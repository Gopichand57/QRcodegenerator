# %%
import qrcode
import matplotlib.pyplot as plt

# %%
data = "https://www.linkedin.com/in/gopichand-moluguri-39a91725b/"
filename = "My_QR_CODE.png"
image = qrcode.make(data)
image.save(filename)
plt.imshow(image,cmap='gray')
